# %%
# creating and writing a file
file=open ("filhand.txt","w")
file.write("i am practicing files in jupiter notebook vs code\n i want to become programmer \n i am very passionateabout programing\n")
file.close()

# %%
#reading a file
with open("filhand.txt",'r') as f:
    read=f.read()
    print(read)
f.close()
# Out:
# ['i am practicing files in jupiter notebook vs code\n', ' i want to become programmer \n', ' i am very passionateabout programing\n']

# %%
#reading a line in file
with open("filhand.txt",'r') as f:
    read=f.readline()
    print(read)
f.close()
# Out:
# i am practicing files in jupiter notebook vs code

# %%
#reading a file and making it in list
with open("filhand.txt",'r') as f:
    read=f.readlines()
    print(read)
f.close()
# Out:
# ['i am practicing files in jupiter notebook vs code\n', ' i want to become programmer \n', ' i am very passionateabout programing\n']

# %%
#reading a file and making it in list
with open("filhand.txt",'r') as f:
    read=f.readable()
    print(read)
f.close()
# Out:
# True

# %%
#working with csv files
# reading or creeating
data={
    "name":"khairbakhsh",
    "marks":"doesnt matter"
}
import csv
with open("creat.csv",'w',newline="") as f:
 f=csv.writer(f)
 f.writerow(data.keys())
 f.writerow(data.values())

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 9
#       7 f=csv.DictReader(f)
#       8 for i in f:
# ----> 9   print(i["names"],i["marks"])
#
# KeyError: 'names'

# %%
data={
    "name":"khairbakhsh",
    "marks":"doesnt matter"
}
import csv
with open("creat.csv",'r') as f:
 f=csv.DictReader(f)
 for i in f:
   print(i["name"],i["marks"])
# Out:
# khairbakhsh doesnt matter

# %%
# 1. Load the provided CSV file (student_data.csv).
# 2. Print only names and cities.
# 3. Add a new row into a new CSV file.
with open("student_data.csv","r") as f:
    f.dictread()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 # 1. Load the provided CSV file (student_data.csv).
#       2 # 2. Print only names and cities.
#       3 # 3. Add a new row into a new CSV file.
# ----> 4 with open("student_data.csv","r") as f:
#       5     f.dictread()
#
# File c:\Users\GT-Tech\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'student_data.csv'

# %%
word=['cat','python','ai','machine']
four=[ i for i in word  if len(i)>4]
print(four)
# Out:
# ['python', 'machine']

# %%
numss=[1,2,3,4]
output = [ "even"if i % 2 == 0  else "odd" for i in numss]
print(output)
# Out:
# ['odd', 'even', 'odd', 'even']

# %%
negative=[-3,4,-1,7]
out=[0 if i <0 else i for i in negative]
print(out)
# Out:
# [0, 4, 0, 7]

# %%
marks=[45,78,90,33]
passed=['pass' if i>50 else 'fail' for i in marks]
print(passed)
# Out:
# ['fail', 'pass', 'pass', 'fail']

# %%
matrix=[
    [1,2],
    [3,4],
    [5,6]
]
for i in matrix:
    for j in i:
     print(matrix)
# Out:
# [[1, 2], [3, 4], [5, 6]]
# [[1, 2], [3, 4], [5, 6]]
# [[1, 2], [3, 4], [5, 6]]
# [[1, 2], [3, 4], [5, 6]]
# [[1, 2], [3, 4], [5, 6]]
# [[1, 2], [3, 4], [5, 6]]

# %%
result=[(i,j ,i*j) for i in range(1,4) for j in range (1,4)]
print(result)
# Out:
# [(1, 1, 1), (1, 2, 2), (1, 3, 3), (2, 1, 2), (2, 2, 4), (2, 3, 6), (3, 1, 3), (3, 2, 6), (3, 3, 9)]

# %%
# set comprehension
nums=[1,2,3,4,5,4]
sq={n*n for n in nums}
print(sq)
# Out:
# {1, 4, 9, 16, 25}

# %%
#for comprehsnsion first out put then loop then condition
#[output ]
text='programingisfun'
vowel='aeiou'
t={i for i in text if i in 'aeiou' }
print(t)
# Out:
# {'i', 'a', 'o', 'u'}

# %%
# ditionary comprehension
 # {key : value  for item in collection }
nums=[1,2,3,4]
square={n :n*n for n in nums }
print(square)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
w=['python','ai','data']
s={n : len(n) for n in w}
print(s)
# Out:
# {'python': 6, 'ai': 2, 'data': 4}

# %%
scores={'ali':80,"zara":45,'ahemed':90}
passing={k:v for k,v in scores.items() if v>=50}
print(passing)
# Out:
# {'ali': 80, 'ahemed': 90}

# %%
names=['ali','zara','ahemed']
na=[]
na=[i.upper() for i in names]
print(na)
# Out:
# ['ALI', 'ZARA', 'AHEMED']

# %%
lis=[i*i for i in range (1,51) if i%2==0]
print(lis)
# Out:
# [4, 16, 36, 64, 100, 144, 196, 256, 324, 400, 484, 576, 676, 784, 900, 1024, 1156, 1296, 1444, 1600, 1764, 1936, 2116, 2304, 2500]

# %%
enter=input("enter a sentence")
even={i for i in enter if i in 'aeiou'}
print(even)
# Out:
# set()

# %%
words={'this','is','a','sample','document','containing','few','words'}
di={v:v[0] for v in words }
print(di)
# Out:
# {'containing': 'c', 'document': 'd', 'is': 'i', 'this': 't', 'words': 'w', 'sample': 's', 'few': 'f', 'a': 'a'}

# %%
# exception handling 10 dec 2025 

try:
    x=int(input("enter a number     :"))
    print(10/x)
except ZeroDivisionError:
    print("you are not allowed to divide by zero")
    #case 2:value eror 
except ValueError:
    print("please enter a valid number")
# Out:
# 2.5

# %%
try:
    x=int(input("enter first number"))
    y=int(input("enter second number"))
    result=x/y
except ZeroDivisionError:
    print("not allowed to divide by 0")
except ValueError:
    print("invalid number")
else:
    print("calculation is success ful")
    print(f'answer  {result:.2f}')
# Out:
# calculation is success ful
# answer  1.00

# %%
try:
    file=open("data.txt","r")
    print(file.read())
except:
    print("file not found")
else:
    print(file.read())
finally:
    print("program finished")
# Out:
# file not found
# program finished

# %%
try:
    num=int(input("enter a number"))
    print(num/0)
except(ValueError,ZeroDivisionError):
    print("invalid number or division error")
# Out:
# invalid number or division error

# %%
numbers=[10,20,30]
try:
    
    index=int(input("enter index"))
    print(numbers[index])
except(ValueError,IndexError):
    print("index out of range or invalid ")
# Out:
# index out of range or invalid

# %%
#key error
student={"name":"babar","runs":76}
try:
    key=input("enter key")
    print(student[key])
except KeyError:
    print("key does not exist")
# Out:
# key does not exist

# %%
age=int(input("enter your age"))
if age<18:
    raise ValueError("age must be 18 or above")

# %%
#date 10 december 2025
#  when any error come in the website or code then whatv is showed is called exception handling
# exception is the run tim error that crushes your program if not handeled 
#for example 
# 1. dividing by zero 
# 2. converting text to number
# 3.accesing invalid index
# 4. file not found
#WHY EXCEPTION HANDLING IS IMPORTANT
#PREVENTS PROGRAM CRASHING '
#ALLOWS PROGRAM TO CONINUE
#REQUIRED IN REAL WORLD (BANKING AND HOSPITALS)
#TRY :RISKY CODE
#EXCEPT:IF ERROR RUN THIS CODE

#case 1 : divide b zero
try:
    x=int(input("enter a number     :"))
    print(10/x)
except ZeroDivisionError:
    print("you are not allowed to divide by zero")
    #case 2:value eror 
except ValueError:
    print("please enter a valid number")
# Out:
# 2.5

# %%
#12 dec 25
# excepton handling
#type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 5
#       1 #12 dec 25
#       2 # excepton handling
#       3 #type error
#       4 age='20'
# ----> 5 print(age+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#syntax error
age=12
if age>18
print('adult')
# Out:
#   Cell In[3], line 2
#     if age>18
#              ^
# SyntaxError: expected ':'

# %%
#indent error
if True:
print("hello")
# Out:
#   Cell In[4], line 3
#     print("hello")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
#index error
num=[1,2,3]
print(num[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 #index error
#       2 num=[1,2,3]
# ----> 3 print(num[3])
#
# IndexError: list index out of range

# %%
#zero division error
x=10
y=0
print(x/y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 x=10
#       2 y=0
# ----> 3 print(x/y)
#
# ZeroDivisionError: division by zero

# %%
#logical error

marks=80
if marks>70:
    print('A grade')
elif marks>70:
    print("Grade B")
elif marks>60:
    print("C")
elif marks>70:
    print('A grade')
elif marks>70:
    print("Grade B")
elif marks>80:
    print("C*")
# Out:
# A grade

# %%
#attribute error
name='python'
print(name.uppercase())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 name='python'
# ----> 2 print(name.uppercase())
#
# AttributeError: 'str' object has no attribute 'uppercase'

# %%
#logic building
#input 
#output
#condition
#loop or repetattion
#data types
#tool specifi operetor method
num=int(input("enter a number"))
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
marks=int(input("enter a number"))
if marks>=40:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
#input==two  numbers
#output print the greater one 
#condition a>b
a=int(input("enter a number"))
b=int(input("enter the second number"))
if a>b:
    print(a)
else:
    print(b)
# Out:
# 7

# %%
#logic building
#input=
#output
#condition (if user name is admin and password 1234)
#loop or repetattion
#data types
#tool specifi operetor method
username=input("enter the user name").lower()
password=input("enter the password")
if username=='admin' and password=='1234':
    print("login succesfully")
else:
    print("wrong password and user name")
# Out:
# wrong password and user name

# %%
#logic building
#input 
#output
#condition      age<13 child 13 and 19 teen and 20 above adult
#loop or repetattion
#data types
#tool specifi operetor method
age=int(input("enter the age"))
if age <=13:
    print("child")
elif age>13 and age<=19:
    print("teen")
elif age >=20:
    print("adult")
# Out:
# adult

# %%
#logic building
#input 
#output
#condition  
#loop or repetattion
#data types
#tool specifi operetor method

# %%
print(bool(99))
# Out:
# True

# %%
for i in range(5,0,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
i=5
while i>=1:
    print(i)
    i=i-1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
sum=0
for i in range(1,6):
    
    sum=sum+i
    i=i+1
print(sum)
# Out:
# 15

# %%
sum=0
i=1
while i<=5:
    
    sum=sum+i
    i=i+1
print(sum)
# Out:
# 15

# %%
nums=[10,20,30,40]
number=int(input("enter a number"))
if number in nums:
    print("found")
else:
    print("not found")
# Out:
# found

# %%
#logic building
#input 
#output
#condition  
#loop or repetattion
#data types
#tool specifi operetor method

# %%
#27 dec 25
#logic building
#input  enter anumber 
#output even divisible
#condition  
#loop or repetattion
#data types
#tool specifi operetor method


num=int(input("enter a number   :"))
if num%2==0 and num %5==0:
    print("even and divisble by 5")
else:
    print("not divisible 5 or not even")
# Out:
# not divisible 5 or not even

# %%
bill=int(input("enter a number"))
if bill>=5000:
    disc=bill*.10
    total=bill-disc
    print("you got 10 percent discount",total)
else:
    print(bill)
# Out:
# 400

# %%
count=0

for  i in range(1,11):
    if i%2==0:
        count=count+1
print(count)
# Out:
# 5

# %%
i=1
count=0
while(i<=11):
    if i%2==0:
        count=count+1
    i+=1
print(count)
# Out:
# 5

# %%
#


i=1
sum=0
while(i<=10):
    if i%2==1:
        sum+=i
    i=i+1
print(sum)
# Out:
# 25

# %%
num=int(input("enter a number "))
is_positive=False
is_even=False
if num %2==0:
    is_even=True
if num>0:
    is_positive=True
print("is number is positive",is_positive)
print("is number is even",is_even)
# Out:
# is number is positive False
# is number is even False

# %%
bill=float(input("enter bill amount"))
member=input("member ship (yes no)").lower()
if bill>=3000:
    dis=bill*0.10
    total=bill-dis
    if member=="yes":
        dis=bill*0.15
        total=bill-dis
        print("your total amount is ",total)
    else:
        print(total)

else:
    print(bill)
# Out:
# 27000.0
